# %% [markdown]
# # Homework 1
#
# Read the paper on volume: https://drive.google.com/drive/folders/1tdNz4ITkbVMU1GkZkyIwPWAmAd9H_fo0?usp=drive_link
#
# - Create a dataframe containing the data used in the paper.
# - Limit the country to usa and the timeframe from 2000 to 2005.
# - choose one ticker (NVDA) and plot each of the features across time
#
# Use this dataset:
# https://drive.google.com/file/d/1QYDnB2XaMs6gyPO0RnT23-0pTPsaBtWk/view?usp=drive_link
#
# Save in your github repository.
# Send the link to my email rbarit@ateneo.edu.

# %%
# import necessary packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# Read prices.csv file

df = pd.read_csv("prices.csv")
df
# Out:
#                              Date        Open        High         Low  \
# 0       2025-07-03 00:00:00-04:00    6.630000    6.740000    6.615000
# 1       2025-07-03 00:00:00-04:00  106.750000  108.370003  106.330101
# 2       2025-07-03 00:00:00-04:00  122.629997  123.050003  121.550003
# 3       2025-07-03 00:00:00-04:00  221.705002  224.009995  221.360001
# 4       2025-07-03 00:00:00-04:00  212.145004  214.649994  211.810104
# ...                           ...         ...         ...         ...
# 310117  2000-01-03 00:00:00-05:00   38.147537   38.255972   35.935457
# 310118  2000-01-03 00:00:00-05:00   25.215814   25.330655   24.690826
# 310119  2000-01-03 00:00:00-05:00   72.313085   72.405794   71.756831
# 310120  2000-01-03 00:00:00-05:00    7.289986    7.342182    7.098602
# 310121  2000-01-03 00:00:00-05:00    5.731675    5.793975    5.427959
#
#              Close      Volume                 Brand_Name Ticker  \
# ...

# %%
# Country is limited to USA
# Time Frame is set from year 2000 to 2005
# NVDA Ticker is Selected for this dataframe

df1 = df[(df["Country"] == "usa") & (df["Date"].between("2000-01-01", "2005-12-31") & (df["Ticker"] == "NVDA"))]
df1
# Out:
#                              Date      Open      High       Low     Close  \
# 257219  2005-12-30 00:00:00-05:00  2.833316  2.834082  2.783623  2.795091
# 257259  2005-12-29 00:00:00-05:00  2.912826  2.922001  2.837139  2.849371
# 257313  2005-12-28 00:00:00-05:00  2.887597  2.923530  2.869249  2.914356
# 257349  2005-12-27 00:00:00-05:00  2.866956  2.918944  2.857782  2.887598
# 257392  2005-12-23 00:00:00-05:00  2.855488  2.873836  2.836375  2.870013
# ...                           ...       ...       ...       ...       ...
# 309967  2000-01-07 00:00:00-05:00  0.783635  0.808720  0.771689  0.800359
# 309997  2000-01-06 00:00:00-05:00  0.842168  0.842168  0.754965  0.787218
# 310053  2000-01-05 00:00:00-05:00  0.845752  0.860087  0.830223  0.842169
# 310071  2000-01-04 00:00:00-05:00  0.879199  0.881589  0.826639  0.870838
# 310101  2000-01-03 00:00:00-05:00  0.903091  0.910259  0.843363  0.894729
#
#             Volume Brand_Name Ticker Industry_Tag Country  Dividends  \
# ...

# %%
# Set Date column to date format

df1['Date'] = pd.to_datetime(df['Date'], utc = True)
df1 = df1.sort_values(by = 'Date', ascending = True)
df1
# Out:
# /var/folders/dq/szp8fjvs6859ycybm39vxqpc0000gp/T/ipykernel_1871/1711143672.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Date'] = pd.to_datetime(df['Date'], utc = True)
#                             Date      Open      High       Low     Close  \
# 310101 2000-01-03 05:00:00+00:00  0.903091  0.910259  0.843363  0.894729
# 310071 2000-01-04 05:00:00+00:00  0.879199  0.881589  0.826639  0.870838
# 310053 2000-01-05 05:00:00+00:00  0.845752  0.860087  0.830223  0.842169
# 309997 2000-01-06 05:00:00+00:00  0.842168  0.842168  0.754965  0.787218
# 309967 2000-01-07 05:00:00+00:00  0.783635  0.808720  0.771689  0.800359
# ...                          ...       ...       ...       ...       ...
# ...

# %%
# Features not used are removed from the dataframe such as Open, High, Low, Close,
# brand name, ticker, industry tag, country, dividends, stock splits, and capital gains

df2 = df1.drop(["Open", "High", "Low", "Close", "Brand_Name", "Ticker", "Industry_Tag", 
                "Country", "Dividends", "Stock Splits", "Capital Gains"], axis = 1)
df2
# Out:
#                             Date      Volume
# 310101 2000-01-03 05:00:00+00:00  30091200.0
# 310071 2000-01-04 05:00:00+00:00  30048000.0
# 310053 2000-01-05 05:00:00+00:00  18835200.0
# 309997 2000-01-06 05:00:00+00:00  12048000.0
# 309967 2000-01-07 05:00:00+00:00   7118400.0
# ...                          ...         ...
# 257392 2005-12-23 05:00:00+00:00  21453600.0
# 257349 2005-12-27 05:00:00+00:00  36796800.0
# 257313 2005-12-28 05:00:00+00:00  26442000.0
# 257259 2005-12-29 05:00:00+00:00  31046400.0
# 257219 2005-12-30 05:00:00+00:00  22960800.0
#
# [1508 rows x 2 columns]

# %%
# Change in Volume (at time = t) = Volume (t) - Volume (t-1)

df2["Volume Change"] = df2["Volume"].diff()

# Set Lag = 1 day using shift function

df2["Lagged Volume"] = df2["Volume"].shift(1)

# Change in Lagged Volume (at time = t) = Lagged Volume (t) - Lagged Volume (t-1)

df2["Lagged Volume Change"] = df2["Lagged Volume"].diff()

# Set Date as index for the dataframe

df2 = df2.set_index("Date")

df2
# Out:
#                                Volume  Volume Change  Lagged Volume  \
# Date
# 2000-01-03 05:00:00+00:00  30091200.0            NaN            NaN
# 2000-01-04 05:00:00+00:00  30048000.0       -43200.0     30091200.0
# 2000-01-05 05:00:00+00:00  18835200.0    -11212800.0     30048000.0
# 2000-01-06 05:00:00+00:00  12048000.0     -6787200.0     18835200.0
# 2000-01-07 05:00:00+00:00   7118400.0     -4929600.0     12048000.0
# ...                               ...            ...            ...
# 2005-12-23 05:00:00+00:00  21453600.0    -10380000.0     31833600.0
# 2005-12-27 05:00:00+00:00  36796800.0     15343200.0     21453600.0
# 2005-12-28 05:00:00+00:00  26442000.0    -10354800.0     36796800.0
# 2005-12-29 05:00:00+00:00  31046400.0      4604400.0     26442000.0
# 2005-12-30 05:00:00+00:00  22960800.0     -8085600.0     31046400.0
#
#                            Lagged Volume Change
# Date
# 2000-01-03 05:00:00+00:00                   NaN
# ...

# %%
# Plotting each of the independent features across time

plot = df2.plot(subplots = True, kind = "line", figsize = (12, 10), legend = True, title = [
    "Volume for NVDA from 2000 to 2005",
    "Volume Change for NVDA from 2000 to 2005",
    "Lagged Volume for NVDA from 2000 to 2005",
    "Lagged Volume Change for NVDA from 2000 to 2005"
])

for p in plot:
    p.xaxis.set_major_locator(mdates.YearLocator())           
    p.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
    p.set_xlim(pd.Timestamp("1999-12-31"), pd.Timestamp("2006-01-01")) 
    p.tick_params(axis="x", rotation=0)
    p.tick_params(labelbottom = True)        

plt.tight_layout()
plt.show()

# %% [markdown]
# # Homework 2
#
# Finish the Pandas course: https://www.kaggle.com/learn/pandas
# Screenshot the completion and send it to my email rbarit@ateneo.edu. Deadline: August 23, 2025 8am.
#
# ![image.png](attachment:34e5fd36-11fc-41ea-a095-f3e5c903bf98.png)

# %% [markdown]
# Highly encouraged to finish:
# - https://www.kaggle.com/learn/intro-to-programming
# - https://www.kaggle.com/learn/python

# %% [markdown]
# #### Done

# %% [markdown]
# ![image.jpeg](46d69b93-c521-4897-838a-f709a5173a64.jpeg)
